# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# ### Exercise 1: Mailing Address
# Create a program that displays your name and complete mailing address formatted in the manner that you would usually see it on
# the outside of an envelope. Your program does not need to read any input from the user.

# %%
Name = "Pratik Singh"
Email = "pratiksingh201811@gmail.com"
print("my name is : ",Name)
print("E-mail id : ",Email)
# Out:
# my name is :  Pratik Singh
# E-mail id :  pratiksingh201811@gmail.com

# %% [markdown]
# ### Exercise 2: Hello
# Write a program that asks the user to enter his or her name. The program should respond with a message that says hello to the
# user, using his or her name

# %%
Name=input("Enter your name : ")
print(" Hello ",Name)
# Out:
# Enter your name : Pratik
#  Hello  Pratik

# %% [markdown]
# ### Exercise 3: Area of a Room
#
# Write a program that asks the user to enter the width and length of a room. Once the values have been read, your program should compute and display the area of the room. The length and the width will be entered as floating point numbers. Include units in your prompt and output message; either feet or meters, depending on which unit you are more comfortable working with.

# %%
L=float(input("Enter the length of the room in feet : "))
W=float(input("Enter the length of the room in feet : "))
A=L*W
print("Area of the room is ",A,"square feet.")
# Out:
# Enter the length of the room in feet : 30.5
# Enter the length of the room in feet : 45.9
# Area of the room is  1399.95 square feet.

# %% [markdown]
# ### Exercise 4: Area of a Field
#
# Create program that reads the length and width of farmer’s field from the user in feet. Display the area of the field in acres.
# Hint: There are 43,560 square feet in an acre.

# %%
L=float(input("Enter the length of the farmer's field  in feet : "))
W=float(input("Enter the length of the farmer's field  in feet : "))
A=L*W
A=A/43560
print("Area of the farmer's field is ",A," acres.")
# Out:
# Enter the length of the farmer's field  in feet : 30.5
# Enter the length of the farmer's field  in feet : 45.9
# Area of the farmer's field is  0.032138429752066114  acres.

# %% [markdown]
# ### Exercise 5: Bottle Deposits
#
# In many jurisdictions a small deposit is added to drink containers to encourage people
# to recycle them. In one particular jurisdiction, drink containers holding one liter or
# less have a $ 0.10 deposit, and drink containers holding more than one liter have a
#  0.25 deposit.
# Write a program that reads the number of containers of each size from the user.
# Your program should continue by computing and displaying the refund that will be
# received for returning those containers. Format the output so that it includes a dollar
# sign and always displays exactly two decimal places.

# %%
number_container = int(input("Enter the number of containers : "))
size_container =  int(input("Enter the size of containers in ML : "))
if (size_container<1000):
    ra = number_container * 0.10
else:
    ra = number_container * 0.25
print("For returning ",number_container, "container's  of size  ML",size_container,"The refund reward amount is",ra)
# Out:
# Enter the number of containers : 5
# Enter the size of containers in ML : 1999
# For returning  5 container's  of size  1999 The refund reward amount is 1.25

# %%
def leap(year):
    if (year%4==0) and (year%100!=0):
        return True
    else:
        return False


year=int(input())
print(leap(year))
# Out:
# 2021
# False

# %% [markdown]
# ## Exercise 6: Tax and Tip

# %% [markdown]
# The program that you create for this exercise will begin by reading the cost of a meal
# ordered at a restaurant from the user. Then your program will compute the tax and
# tip for the meal. Use your local tax rate when computing the amount of tax owing.
# Compute the tip as 18 percent of the meal amount (without the tax). The output from
# your program should include the tax amount, the tip amount, and the grand total for
# the meal including both the tax and the tip. Format the output so that all of the values
# are displayed using two decimal places

# %%
cost=float(input("Enter the cost of meals : "))
tip=(18*cost)/100
tax=(30*cost)/100
grand_total=cost+tip+tax
print(f'Total cost of a meal is {grand_total}')
# Out:
# Enter the cost of meals : 100
# Total cost of a meal is 148.0

# %% [markdown]
# ##  Exercise 7: Sum of the First n Positive Integers

# %% [markdown]
# Write a program that reads a positive integer, n, from the user and then displays the sum of all of the integers from 1 to n. The sum of the first n positive integers can be computed using the formula:
#
# sum =((n)(n + 1))/2

# %%
n=int(input("Enter the first n natural number : "))
if n>=0:
    summ=((n)*(n+1))/2
    print(f"Sum of {n} natural number is {summ}.")
else:
    print("Please enter positive numbers.")
# Out:
# Enter the first n natural number : 10
# Sum of 10 natural number is 55.0.
